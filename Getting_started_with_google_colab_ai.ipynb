# %% [markdown]
# Colab is making it easier than ever to integrate powerful Generative AI capabilities into your projects. We are launching public preview for a simple and intuitive Python library (google.colab.ai) to access state-of-the-art language models directly within Colab environments. All users have free access to most popular LLMs, while paid users have access to a wider selection of models. This means users can spend less time on configuration and set up and more time bringing their ideas to life. With just a few lines of code, you can now perform a variety of tasks:
# - Generate text
# - Translate languages
# - Write creative content
# - Categorize text
#
# Happy Coding!
#
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/Getting_started_with_google_colab_ai.ipynb)

# %%
# @title List available models
from google.colab import ai

ai.list_models()
# Out:
# ['google/gemini-2.5-flash-lite', 'google/gemini-3.5-flash']

# %% [markdown]
# Choosing a Model
# The model names give you a hint about their capabilities and intended use:

# %%
# @title Simple batch generation example
# Only text-to-text input/output is supported
from google.colab import ai

response = ai.generate_text("What is the capital of France?")
print(response)
# Out:
# The capital of France is **Paris**.

# %%
response = ai.generate_text("대한민국의 수도는? 경복국에 대해 설명해줘")
print(response)
# Out:
# 대한민국의 수도는 **서울특별시**입니다.
#
# 질문해주신 **경복궁**(‘경복국’은 경복궁의 오타로 보입니다)에 대해 자세히 설명해 드리겠습니다.
#
# ---
#
# ### 경복궁(景福宮)이란?
#
# 경복궁은 조선 시대에 지어진 **5대 궁궐(경복궁, 창덕궁, 창경궁, 덕수궁, 경희궁) 중 가장 처음으로 지어진 으뜸 궁궐(법궁, 法宮)**입니다.
#
# '경복(景福)'이라는 이름은 **"새 왕조가 큰 복을 누려 번창할 것이다"**라는 뜻을 담고 있으며, 조선의 개국공신인 정도전이 지었습니다.
#
# #### 1. 역사
# * **창건 (1395년):** 조선을 건국한 태조 이성계가 한양(지금의 서울)으로 수도를 옮기면서 지었습니다.
# * **소실 (1592년):** 임진왜란 때 불에 타서 완전히 무너졌습니다. 이후 약 270년 동안 복구되지 못하고 방치되어 있었습니다. (이 기간 동안 조선의 왕들은 창덕궁을 주로 사용했습니다.)
# * **중건 (1867년):** 흥선대원군의 주도로 조선 왕실의 권위를 높이기 위해 다시 크게 지어졌습니다.
# * **수난과 복원:** 일제강점기 때 많은 건물들이 훼손되고 궁궐 안에 조선총독부 건물이 들어서는 등 큰 아픔을 겪었습니다. 1990년대부터 본격적인 복원 사업이 시작되어 지금도 옛 모습을 되찾는 작업이 계속되고 있습니다.
#
# #### 2. 대표적인 주요 건물
# * **광화문(光化門):** 경복궁의 남쪽에 있는 정문입니다. 세 개의 홍예문(아치형 문)이 있는 것이 특징입니다.
# * **근정전(勤政殿):** 경복궁의 중심 건물(국보)로, 왕이 즉위식을 하거나 외국 사신을 맞이하는 등 국가의 공식적인 대형 행사를 치르던 곳입니다.
# * **경회루(慶會樓):** 연못 위에 세워진 아름다운 누각(국보)입니다. 왕이 신하들과 연회를 베풀거나 외국 사신을 대접하던 곳으로, 경복궁에서 가장 아름다운 경치를 자랑하는 곳 중 하나입니다.
# * **향원정(香遠亭):** 경복궁 북쪽 후원에 있는 아담한 연못과 정자로, 고종과 명성황후가 휴식을 취하던 사적인 공간입니다.
#
# #### 3. 관람 정보 및 팁
# * **위치:** 서울특별시 종로구 사직로 161 (지하철 3호선 경복궁역과 바로 연결됩니다.)
# * **수문장 교대의식:** 광화문 앞에서 조선 시대 수문장들의 교대 의식을 재현하는 행사가 매일 열려 관광객들에게 인기가 많습니다.
# * **한복 착용 혜택:** 한복을 입고 경복궁에 가면 **입장료가 무료**입니다. 주변에 한복 대여점이 많아 국내외 관광객들이 한복을 입고 사진을 찍는 명소로 유명합니다.
# * **야간 개장:** 봄과 가을에는 특별 야간 개장을 진행하는데, 조명을 받은 경복궁의 밤풍경이 매우 아름답습니다.

# %%
# @title Choose a different model
from google.colab import ai

response = ai.generate_text("What is the capital of England",
                            model_name='google/gemini-2.5-flash-lite')
print(response)
# Out:
# The capital of England is **London**.

# %% [markdown]
# For longer text generations, you can stream the response. This displays the output token by token as it's generated, rather than waiting for the entire response to complete. This provides a more interactive and responsive experience. To enable this, simply set stream=True.

# %%
# @title Simple streaming example
from google.colab import ai

stream = ai.generate_text("Tell me a short story.", stream=True)
for text in stream:
  print(text, end='')
# Out:
# The clock on the wall of the archives didn’t tick; it hummed.
#
# Elias preferred the hum. It matched the low vibration of the thousands of glass jars lining the floor-to-ceiling shelves. Elias was a Curator of Lost Things, though his specific department was highly specialized. He didn’t collect keys, umbrellas, or misplaced wedding rings.
#
# Elias collected the things people forgot they had said.
#
# He walked down Aisle 14 (Unspoken Regrets and Abrupt Departures) carrying a brass cart. On it sat a single, empty jar made of hand-blown lead crystal. It was heavy, designed to contain high-pressure sentiments.
#
# He stopped in front of shelf 42. He checked his pocket watch. It was 3:14 PM.
#
# Across the city, in a crowded coffee shop, a young woman named Clara was about to make a choice. She was looking at her childhood best friend, who was moving to another country in three hours. There was a sentence sitting on the tip of Clara’s tongue—a confession of love that had kept her awake for three years.
#
# Elias unscrewed the lid of the crystal jar. He held it open, tilting it slightly toward the air, though the archive was miles away from the cafe.
#
# In the coffee shop, Clara took a breath. Her heart hammered. She opened her mouth.
#
# *“Safe travels,”* she said instead. *“Don't forget to text.”*
#
# A mile away, in the archive, a soft, golden vapor materialized inside Elias’s jar. It swirled violently, a miniature storm of warmth, smelling faintly of rain and old books.
#
# Elias quickly sealed the jar. The vapor pressed against the glass, desperate to be heard, before slowly settling into a glowing, quiet liquid at the bottom.
#
# He took a fountain pen and wrote on the label in elegant, cursive script:
# *Clara V. — "I have loved you since the day we met on the library steps." — March 12th.*
#
# He placed the jar on the shelf next to thousands of others. To its left was a jar from 1954 (*"I'm sorry I blamed you"*), and to its right, a dusty bottle from 1889 (*"I never wanted to leave the farm"*).
#
# Sometimes, people came back for them. Once in a great while, a person would walk into the archive, their chest feeling inexplicably light but empty, and ask to retrieve a word they had dropped. Elias would find the jar, unscrew the lid, and let them inhale the vapor. They would go back out into the world, find the person they had left behind, and finally speak.
#
# But most jars remained on the shelves forever, glowing softly in the dark.
#
# Elias dusted the lid of Clara’s jar, gave it a gentle pat, and pushed his cart back down the aisle. He had to get to Aisle 9. A boy in London was about to decide not to tell his father he forgave him, and the jar for that was particularly delicate.None

# %%
#@title Text formatting setup
#code is not necessary for colab.ai, but is useful in fomatting text chunks
import sys

class LineWrapper:
    def __init__(self, max_length=80):
        self.max_length = max_length
        self.current_line_length = 0

    def print(self, text_chunk):
        i = 0
        n = len(text_chunk)
        while i < n:
            start_index = i
            while i < n and text_chunk[i] not in ' \n': # Find end of word
                i += 1
            current_word = text_chunk[start_index:i]

            delimiter = ""
            if i < n: # If not end of chunk, we found a delimiter
                delimiter = text_chunk[i]
                i += 1 # Consume delimiter

            if current_word:
                needs_leading_space = (self.current_line_length > 0)

                # Case 1: Word itself is too long for a line (must be broken)
                if len(current_word) > self.max_length:
                    if needs_leading_space: # Newline if current line has content
                        sys.stdout.write('\n')
                        self.current_line_length = 0
                    for char_val in current_word: # Break the long word
                        if self.current_line_length >= self.max_length:
                            sys.stdout.write('\n')
                            self.current_line_length = 0
                        sys.stdout.write(char_val)
                        self.current_line_length += 1
                # Case 2: Word doesn't fit on current line (print on new line)
                elif self.current_line_length + (1 if needs_leading_space else 0) + len(current_word) > self.max_length:
                    sys.stdout.write('\n')
                    sys.stdout.write(current_word)
                    self.current_line_length = len(current_word)
                # Case 3: Word fits on current line
                else:
                    if needs_leading_space:
                        # Define punctuation that should not have a leading space
                        # when they form an entire "word" (token) following another word.
                        no_leading_space_punctuation = {
                            ",", ".", ";", ":", "!", "?",        # Standard sentence punctuation
                            ")", "]", "}",                     # Closing brackets
                            "'s", "'S", "'re", "'RE", "'ve", "'VE", # Common contractions
                            "'m", "'M", "'ll", "'LL", "'d", "'D",
                            "n't", "N'T",
                            "...", "…"                          # Ellipses
                        }
                        if current_word not in no_leading_space_punctuation:
                            sys.stdout.write(' ')
                            self.current_line_length += 1
                    sys.stdout.write(current_word)
                    self.current_line_length += len(current_word)

            if delimiter == '\n':
                sys.stdout.write('\n')
                self.current_line_length = 0
            elif delimiter == ' ':
                # If line is full and a space delimiter arrives, it implies a wrap.
                if self.current_line_length >= self.max_length:
                    sys.stdout.write('\n')
                    self.current_line_length = 0

        sys.stdout.flush()

# %%
# @title Formatted streaming example
from google.colab import ai

wrapper = LineWrapper()
for chunk in ai.generate_text('Give me a long winded description about the evolution of the Roman Empire.', model_name='google/gemini-2.5-flash', stream=True):
  wrapper.print(chunk)
# Out:
# The Roman Empire, that colossal edifice of human ambition, ingenuity, and
# brutality, did not spring forth fully formed like Minerva from Jupiter's head.
# Instead, its evolution was a sprawling, complex, and often contradictory
# tapestry woven over more than a millennium, from a humble settlement on the
# Tiber to the undisputed master of the Mediterranean world, only to then endure a
# protracted, agonizing, and ultimately transformative decline.
#
# Our journey begins not with an empire, but with a **small, struggling
# settlement** of Latins on the banks of the Tiber, imbued with a potent myth of
# Trojan refugees and divine patronage. Legend tells of Romulus and Remus, of
# fratricide and the founding of Rome in 753 BCE. This early period, the **Regal
# Period**, saw Rome governed by kings, first Latin, then Etruscan. These shadowy
# monarchs laid some foundational stones: rudimentary political structures,
# religious institutions, and the very concept of *imperium* – the supreme
# executive power. Even then, the seeds of Roman tenacity were evident, in their
# constant skirmishes with neighboring tribes, their adoption and adaptation of
# Etruscan culture, and their burgeoning sense of identity.
#
# The dramatic expulsion of the last king, Tarquin the Proud, around 509 BCE,
# marked the birth of the ** Roman Republic**. This was Rome's crucible, forging
# the institutions, values, and military might that would define its expansion.
# The early Republic was a period of intense internal struggle between the
# patricians (the aristocratic elite) and the plebeians (the common citizens).
# This friction, surprisingly, became a source of strength. Through centuries of
# conflict and compromise, plebeians gained rights, representation (like the
# Tribunes of the Plebs), and eventually equality under the law (symbolized by the
# Twelve Tables). This internal evolution fostered a robust, if sometimes
# tumultuous, political system that valued law, civic duty (*pietas*), and a
# pragmatic approach to governance. Externally, the Republic engaged in an
# inexorable march across the Italian peninsula, conquering or absorbing its
# neighbors through a combination of military prowess, strategic alliances, and
# the brilliant innovation of extending Roman citizenship (or Latin rights) to
# conquered peoples, thus integrating them into the Roman system rather than
# merely subjugating them. The Samnite Wars and the Latin War are testament to
# this formative period of expansion and assimilation.
#
# The **Middle Republic** witnessed Rome's meteoric rise to a Mediterranean
# superpower. The titanic struggle against Carthage in the Punic Wars
# (particularly the Second Punic War, featuring Hannibal's audacious invasion) was
# the ultimate test of Roman resolve. Their eventual victory, bought at immense
# cost, left Rome without a serious rival in the western Mediterranean. Subsequent
# wars against the Hellenistic kingdoms to the East (Macedonia, the Seleucid
# Empire) solidified Rome's hegemony, bringing vast wealth, new provinces, and a
# flood of Greek culture and philosophy into the Roman sphere. This era saw the
# emergence of the Roman legion as the most effective fighting force of its age, a
# disciplined, adaptable war machine fueled by a citizen-soldier ethos. But this
# very success sowed the seeds of future crisis. The influx of wealth, slaves, and
# conquered land led to the creation of vast *latifundia* (large estates) owned by
# the elite, displacing small farmers and creating a disenfranchised urban
# proletariat.
#
# The **Late Republic** was a century of profound turmoil, a period where the
# traditional republican institutions, designed for a city-state, strained and
# ultimately buckled under the weight of an empire. The Gracchi brothers' attempts
# at land reform, Marius's professionalization of the army (making soldiers loyal
# to their general rather than the state), Sulla's bloody proscriptions, and the
# rise of charismatic military strongmen like Pompey, Crassus, and Caesar, all
# underscored the accelerating breakdown of the *res publica*. Ambition, personal
# loyalty, and military might increasingly trumped civic virtue and constitutional
# law. The recurring cycle of civil wars, culminating in the titanic clash between
# Octavian and Mark Antony, brought the Republic to its knees, paving the way for
# a radical transformation.
#
# Out of this chaos emerged Oct avian, later **Augustus**, who masterfully
# orchestrated the transition from Republic to **Principate** (the first phase of
# the Empire). While ostensibly "restoring" the Republic, Augustus subtly amassed
# unprecedented personal power, becoming *princeps* (first citizen), tribune,
# censor, and commander of all legions. He created a new political order that
# masked autocratic rule under a veil of republican tradition. His genius lay in
# his pragmatism, his administrative reforms, and his ability to project an image
# of peace and stability after decades of war. This ushered in the **Pax Romana**,
# a two-century golden age of unprecedented peace, prosperity, and cultural
# flourishing.
#
# The **High Empire** (roughly 96 CE to 180 CE), particularly under the "Five Good
# Emperors" (Nerva, Trajan, Hadrian, Antoninus Pius, Marcus Aurelius), represented
# Rome at its zenith. The empire stretched from Britannia to Mesopotamia, from the
# Rhine to the Sahara. Roman law, engineering, and administration knitted this
# vast dominion together. Roads, aqueducts, forums, and temples proliferated,
# Romanization spread, and trade flourished. This was an era of consolidation
# rather than aggressive expansion, of internal development and the refinement of
# imperial governance. The Emperor, while still theoretically bound by law, was
# increasingly viewed as a divine or semi-divine figure, and the bureaucracy grew
# in size and complexity.
#
# However, beneath this glittering surface, tensions simmered. The vast size of
# the empire made defense increasingly difficult and expensive. The reliance on
# slave labor hindered technological innovation. A bloated bureaucracy and an
# ever-expanding military drained the imperial coffers. The cult of the emperor,
# while offering stability, also stifled political participation and bred a
# culture of deference.
#
# The **Crisis of the Third Century** (235-284 CE) shattered the Pax Romana,
# exposing the fundamental fragility of the imperial system. A rapid succession of
# " Barracks Emperors" – military commanders who seized power through force and
# were often quickly overthrown – plunged the empire into anarchy. Economic
# collapse, rampant inflation, devastating plagues, and relentless barbarian
# incursions on all frontiers pushed Rome to the brink of dissolution. The very
# fabric of Roman society began to fray. Cities fortified themselves, trade routes
# became dangerous, and local self-sufficiency replaced grand imperial networks.
#
# The empire was saved from immediate collapse by the extraordinary reforms of
# **Diocletian** and **Constantine**. Diocletian recognized that one man could not
# govern such a vast empire and instituted the **Tetrarchy**, dividing the empire
# into East and West, each with an Augustus and a Caesar. He also implemented
# sweeping administrative, military, and economic reforms, centralizing power,
# fixing prices, and establishing a rigorous tax system. This marked the
# definitive shift from the Principate to the **Dominate**, an overtly autocratic
# system where the emperor was an absolute monarch, often seen as a divine figure,
# removed from his subjects.
#
# Constantine, who eventually dismantled the Tetrarchy to become sole emperor,
# continued Diocletian's autocratic trend. His most profound impact, however, was
# his embrace of Christianity. The **Edict of Milan** (313 CE) legalized
# Christianity, and by the end of his reign, it was becoming the favored religion
# of the empire. He also founded a new capital, Constantinople, on the Bosporus,
# strategically positioned at the crossroads of East and West. This decision would
# have monumental consequences, cementing the administrative and cultural
# divergence between the Greek-speaking East and the Latin-speaking West.
#
# The **Late Empire** saw this divergence deepen. While the East, with its richer
# urban centers and more robust economy, largely weathered the storms, the West
# faced an escalating, existential crisis. Pressures from migrating barbarian
# tribes (Goths, Vandals, Huns, Franks), pushed westward by nomadic incursions
# from Asia, became insurmountable. Repeated sacks of Rome itself (410 CE by the
# Visigoths, 455 CE by the Vandals) were stark symbols of imperial weakness.
# Economic decline, overtaxation, political corruption, and a shrinking population
# further eroded the Western Empire's ability to resist. The once-mighty legions
# were increasingly composed of barbarian mercenaries, and loyalty to the distant
# emperor waned.
#
# The traditional date for the **Fall of the Western Roman Empire** is 476 CE,
# when the last Western Roman Emperor, Romulus Augustulus, was deposed by the
# Germanic chieftain Odoacer. Yet, this was less a cataclysmic collapse and more
# the culmination of a long, drawn-out process of fragmentation and
# transformation. The structures of the empire didn't vanish overnight; they
# dissolved, fragmented, and were reconfigured into the various Germanic kingdoms
# that would become the foundations of medieval Europe. Roman law, Latin language,
# and Christian faith (albeit in a newly developing form) persisted, evolving in
# these successor states.
#
# Meanwhile, the **Eastern Roman Empire**, centered in Constantinople, continued
# to thrive for another thousand years, becoming what we now know as the
# **Byzantine Empire**. It preserved Roman law, administration, and imperial
# tradition, albeit with an increasingly Greek identity and an Orthodox Christian
# faith. This "second Rome" serves as a powerful testament to the enduring legacy
# and adaptability of Roman civilization, even as its western counterpart faded
# into a complex, fragmented tapestry of barbarian kingdoms.
#
# The evolution of the Roman Empire is a profound lesson in the rise and fall of
# civilizations. It showcases incredible resilience and adaptability, a genius for
# organization and law, and an unparalleled military machine. But it also
# demonstrates the inherent tensions within a vast, diverse empire: the struggle
# between liberty and order, expansion and overstretch, internal cohesion and
# external pressures, tradition and innovation. Its trajectory from a small
# village to the master of the world, and then its eventual, multifaceted decline,
# continues to fascinate and inform our understanding of power, governance, and
# human destiny.
